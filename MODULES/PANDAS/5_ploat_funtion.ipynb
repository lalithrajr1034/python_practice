# %%
import matplotlib as plt
import pandas as pd

# %%
data = pd.read_csv("matches.csv")

# %%
data['winner'].value_counts().plot(kind='barh')#pie, bar, line, hist, scatter and more
# Out:
# <Axes: ylabel='winner'>
